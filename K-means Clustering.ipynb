# %% [markdown]
# # K-means Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv('Mall_Customers.csv')
df.describe
df.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#x = df.values[:,1:4]
#y = df.values[:,4]

# %%
x , y_true = make_blobs(n_samples = 300, centers = 4 , random_state = 0)
plt.scatter(x[:,0] , x[:,1], s = 50)

# %%
sum_of_squared_distance = []
K = range(1,16)
for k in K:
    km = KMeans(n_clusters = k)
    km = km.fit(x)
    sum_of_squared_distance.append(km.inertia_)
    y_pred = km.predict(x)

# %%
plt.plot(K , sum_of_squared_distance, 'bx-')
plt.xlabel("K")
plt.ylabel("sum_of_squared_distance")
plt.title("Elbow Method for Optimal k")
#plt.legend()
plt.show()

# %%
plt.scatter(x[:,0] , x[:,1],c=y_pred, s = 20 , cmap = 'summer')
centers = KMeans.cluster_centers_

plt.scatter(centers[:,0] , centers[:,1], c= 'blue', s = 100, alpha = 0.9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-6042b1cbf59c> in <module>
#       1 plt.scatter(x[:,0] , x[:,1],c=y_pred, s = 20 , cmap = 'summer')
# ----> 2 centers = KMeans.cluster_centers_
#       3
#       4 plt.scatter(centers[:,0] , centers[:,1], c= 'blue', s = 100, alpha = 0.9)
#       5 plt.show()
#
# AttributeError: type object 'KMeans' has no attribute 'cluster_centers_'
